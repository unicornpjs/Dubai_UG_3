# %%
import sys
# !{sys.executable} -m pip install keras
# !{sys.executable} -m pip install tensorflow
# !{sys.executable} -m pip install nbconvert
# !{sys.executable} -m pip install colorspacious
# Out:
# Requirement already satisfied: keras in c:\users\egtll\anaconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: absl-py in c:\users\egtll\anaconda3\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\egtll\anaconda3\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\egtll\anaconda3\lib\site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in c:\users\egtll\anaconda3\lib\site-packages (from keras) (0.0.7)
# Requirement already satisfied: h5py in c:\users\egtll\anaconda3\lib\site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in c:\users\egtll\anaconda3\lib\site-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in c:\users\egtll\anaconda3\lib\site-packages (from keras) (0.4.0)
# Requirement already satisfied: packaging in c:\users\egtll\anaconda3\lib\site-packages (from keras) (23.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\egtll\anaconda3\lib\site-packages (from optree->keras) (4.11.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\egtll\anaconda3\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\egtll\anaconda3\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\egtll\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)
# Requirement already satisfied: tensorflow in c:\users\egtll\anaconda3\lib\site-packages (2.17.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.66.2)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.1)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\egtll\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\egtll\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\egtll\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\egtll\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\users\egtll\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\egtll\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\egtll\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\egtll\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\egtll\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\egtll\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\egtll\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\egtll\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\egtll\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\egtll\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\egtll\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\egtll\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.0)
# Requirement already satisfied: nbconvert in c:\users\egtll\anaconda3\lib\site-packages (7.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (3.1.4)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (5.9.2)
# Requirement already satisfied: packaging in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (1.2.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\egtll\anaconda3\lib\site-packages (from nbconvert) (5.14.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\egtll\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\egtll\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\egtll\anaconda3\lib\site-packages (from jupyter-core>=4.7->nbconvert) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\egtll\anaconda3\lib\site-packages (from jupyter-core>=4.7->nbconvert) (305.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\egtll\anaconda3\lib\site-packages (from nbclient>=0.5.0->nbconvert) (8.6.0)
# Requirement already satisfied: fastjsonschema in c:\users\egtll\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\egtll\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert) (4.19.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\egtll\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert) (2.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\egtll\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\egtll\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\egtll\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\egtll\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\egtll\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\egtll\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (25.1.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\egtll\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (6.4.1)
# Requirement already satisfied: colorspacious in c:\users\egtll\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: numpy in c:\users\egtll\anaconda3\lib\site-packages (from colorspacious) (1.26.4)

# %%
import os
from pathlib import Path
from keras.preprocessing import image
import matplotlib.pyplot as plt

from colorspacious import cspace_converter
from matplotlib import colormaps
import matplotlib as mpl

import numpy as np

# %%
p = Path("./Dataset/train_another")
dirs = p.glob("*")

image_data = []
labels = []
label_dict = {"damage":0,"no_damage":1}
bin_to_label = {0:"damage",1:"no_damage"}

for folder_dir in dirs:
    label = str(folder_dir).split("\\")[-1]
    print(label)
    cnt = 0
    print(folder_dir)

    for img_path in folder_dir.glob("*.jpeg"):
        img = image.load_img(img_path,target_size=(128,128))
        img_array = image.img_to_array(img)
        image_data.append(img_array)
        labels.append(label_dict[label])
        cnt +=1
    
    print(cnt)
# Out:
# damage
# Dataset\train_another\damage
# 5000
# no_damage
# Dataset\train_another\no_damage
# 5000

# %%
print(len(image_data))
print(len(labels))
# Out:
# 10000
# 10000

# %%
x = np.array(image_data)
y = np.array(labels)

print(x.shape)
print(y.shape)
# Out:
# (10000, 128, 128, 3)
# (10000,)

# %%
def drawImg(img, label):
    plt.title(bin_to_label[label])
    plt.imshow(img)
    plt.show()

def drawImgBW(img,label):
    gray_img = rgb2gray(img)
    plt.title(bin_to_label[label])
    plt.imshow(gray_img, cmap='terrain')
    plt.show()

drawImg(x[1]/255.0,y[1])
drawImgBW(x[1]/255.0,y[1])
drawImg(x[3500]/255.0,y[3500])
drawImgBW(x[3500]/255.0,y[3500])
drawImg(x[4800]/255.0,y[4800])
drawImgBW(x[4800]/255.0,y[4800])

drawImg(x[5100]/255.0,y[5100])
drawImgBW(x[5100]/255.0,y[5100])
drawImg(x[8000]/255.0,y[8000])
drawImgBW(x[8000]/255.0,y[8000])
drawImg(x[9400]/255.0,y[9400])
drawImgBW(x[9400]/255.0,y[9400])

#for i in range(10):
 #   r = np.random.randint(10000)
  #  drawImg(x[r]/255.0,y[r])
   # drawImgBW(x[r]/255.0,y[r])
